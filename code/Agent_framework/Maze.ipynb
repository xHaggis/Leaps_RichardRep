# %% [markdown]
# # Load useful packages

# %%
import matplotlib
matplotlib.use('TkAgg')  # avoid non-GUI warning for matplotlib

from IPython.display import display, HTML

from gym_maze.envs import MazeEnv
from gym_maze.envs.generators import SimpleMazeGenerator, RandomMazeGenerator, RandomBlockMazeGenerator, \
                                     UMazeGenerator, TMazeGenerator, WaterMazeGenerator
from gym_maze.envs.Astar_solver import AstarSolver

# %% [markdown]
# # Solve maze with A* planner and generate video animiation

# %%
def solvemaze(maze, action_type='VonNeumann', render_trace=False, gif_file='video.gif'):
    env = MazeEnv(maze, action_type=action_type, render_trace=render_trace)
    env.reset()

    # Solve maze by A* search from current state to goal
    solver = AstarSolver(env, env.goal_states[0])
    if not solver.solvable():
        raise Error('The maze is not solvable given the current state and the goal state')

    for action in solver.get_actions():
        env.step(action)
        fig = env.render()

    return env._get_video(interval=200, gif_path=gif_file).to_html5_video()

# %% [markdown]
# # Simple empty maze

# %%
maze = RandomBlockMazeGenerator(maze_size=4, obstacle_ratio=0.0)

anim = solvemaze(maze, action_type='VonNeumann', render_trace=True, gif_file='data/simple_empty_maze.gif')
HTML(anim)
# Out:
# MovieWriter imagemagick unavailable.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     169         try:
# --> 170             return self.avail[name]
#     171         except KeyError:
#
# KeyError: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-e37c515f6af0> in <module>()
#       1 maze = RandomBlockMazeGenerator(maze_size=4, obstacle_ratio=0.0)
#       2
# ----> 3 anim = solvemaze(maze, action_type='VonNeumann', render_trace=True, gif_file='data/simple_empty_maze.gif')
#       4 HTML(anim)
#
# <ipython-input-2-da3e6d802fac> in solvemaze(maze, action_type, render_trace, gif_file)
#      12         fig = env.render()
#      13
# ---> 14     return env._get_video(interval=200, gif_path=gif_file).to_html5_video()
#
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1347                 # We create a writer manually so that we can get the
#    1348                 # appropriate size for the tag
# -> 1349                 Writer = writers[rcParams['animation.writer']]
#    1350                 writer = Writer(codec='h264',
#    1351                                 bitrate=rcParams['animation.bitrate'],
#
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     171         except KeyError:
#     172             raise RuntimeError(
# --> 173                 'Requested MovieWriter ({}) not available'.format(name))
#     174
#     175
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %% [markdown]
# # Random block maze

# %%
maze = RandomBlockMazeGenerator(maze_size=30, obstacle_ratio=0.2)

anim = solvemaze(maze, action_type='VonNeumann', render_trace=True, gif_file='data/random_block_maze.gif')
HTML(anim)
# Out:
# MovieWriter imagemagick unavailable.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     169         try:
# --> 170             return self.avail[name]
#     171         except KeyError:
#
# KeyError: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-dc8b530fd7a1> in <module>()
#       1 maze = RandomBlockMazeGenerator(maze_size=30, obstacle_ratio=0.2)
#       2
# ----> 3 anim = solvemaze(maze, action_type='VonNeumann', render_trace=True, gif_file='data/random_block_maze.gif')
#       4 HTML(anim)
#
# <ipython-input-2-da3e6d802fac> in solvemaze(maze, action_type, render_trace, gif_file)
#      12         fig = env.render()
#      13
# ---> 14     return env._get_video(interval=200, gif_path=gif_file).to_html5_video()
#
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1347                 # We create a writer manually so that we can get the
#    1348                 # appropriate size for the tag
# -> 1349                 Writer = writers[rcParams['animation.writer']]
#    1350                 writer = Writer(codec='h264',
#    1351                                 bitrate=rcParams['animation.bitrate'],
#
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     171         except KeyError:
#     172             raise RuntimeError(
# --> 173                 'Requested MovieWriter ({}) not available'.format(name))
#     174
#     175
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %% [markdown]
# # Random maze

# %%
maze = RandomMazeGenerator(width=20, height=15, complexity=.75, density=.75)

anim = solvemaze(maze, action_type='VonNeumann', render_trace=True, gif_file='data/random_maze.gif')
HTML(anim)
# Out:
# MovieWriter imagemagick unavailable.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     169         try:
# --> 170             return self.avail[name]
#     171         except KeyError:
#
# KeyError: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-c8ef7fe38976> in <module>()
#       1 maze = RandomMazeGenerator(width=20, height=15, complexity=.75, density=.75)
#       2
# ----> 3 anim = solvemaze(maze, action_type='VonNeumann', render_trace=True, gif_file='data/random_maze.gif')
#       4 HTML(anim)
#
# <ipython-input-2-da3e6d802fac> in solvemaze(maze, action_type, render_trace, gif_file)
#      12         fig = env.render()
#      13
# ---> 14     return env._get_video(interval=200, gif_path=gif_file).to_html5_video()
#
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1347                 # We create a writer manually so that we can get the
#    1348                 # appropriate size for the tag
# -> 1349                 Writer = writers[rcParams['animation.writer']]
#    1350                 writer = Writer(codec='h264',
#    1351                                 bitrate=rcParams['animation.bitrate'],
#
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     171         except KeyError:
#     172             raise RuntimeError(
# --> 173                 'Requested MovieWriter ({}) not available'.format(name))
#     174
#     175
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %% [markdown]
# # U-maze

# %%
maze = UMazeGenerator(len_long_corridor=14, len_short_corridor=4, width=4, wall_size=4)

anim = solvemaze(maze, action_type='VonNeumann', render_trace=True, gif_file='data/U_maze.gif')
HTML(anim)
# Out:
# MovieWriter imagemagick unavailable.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     169         try:
# --> 170             return self.avail[name]
#     171         except KeyError:
#
# KeyError: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-a2fd22c55048> in <module>()
#       1 maze = UMazeGenerator(len_long_corridor=14, len_short_corridor=4, width=4, wall_size=4)
#       2
# ----> 3 anim = solvemaze(maze, action_type='VonNeumann', render_trace=True, gif_file='data/U_maze.gif')
#       4 HTML(anim)
#
# <ipython-input-2-da3e6d802fac> in solvemaze(maze, action_type, render_trace, gif_file)
#      12         fig = env.render()
#      13
# ---> 14     return env._get_video(interval=200, gif_path=gif_file).to_html5_video()
#
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1347                 # We create a writer manually so that we can get the
#    1348                 # appropriate size for the tag
# -> 1349                 Writer = writers[rcParams['animation.writer']]
#    1350                 writer = Writer(codec='h264',
#    1351                                 bitrate=rcParams['animation.bitrate'],
#
# ~/leaps/lib/python3.6/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     171         except KeyError:
#     172             raise RuntimeError(
# --> 173                 'Requested MovieWriter ({}) not available'.format(name))
#     174
#     175
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %% [markdown]
# # Multiple T-maze

# %%
maze = TMazeGenerator(3, [5, 3], [3, 3])

anim = solvemaze(maze, action_type='VonNeumann', render_trace=True, gif_file='data/T_maze.gif')
HTML(anim)
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# # Morris water maze

# %%
maze = WaterMazeGenerator(20, 4)

anim = solvemaze(maze, action_type='Moore', render_trace=True, gif_file='data/morris_water_maze.gif')
HTML(anim)
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
